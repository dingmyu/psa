# %%
import numpy as np
import cv2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
xx = np.load('result_cam/2007_000032.npy').item()

# %%
plt.imshow(xx[14])

# %%
plt.imshow(xx[0])

# %%
xx[0].mean()
# Out:
# 0.09714248

# %%
xx[14].mean()
# Out:
# 0.029555084

# %%
plt.imshow(cv2.imread('result_cam_pred/2007_000032.png'))

# %%
plt.imshow(cv2.imread('../VOC2012/JPEGImages/2007_000032.jpg'))

# %%
xx1 = np.load('result_ha_crf/2007_000032.npy').item()

# %%
plt.imshow(xx1[0])

# %%
plt.imshow(xx1[1])

# %%
plt.imshow(xx1[15])

# %%
xx2 = np.load('result_la_crf/2007_000032.npy').item()

# %%
plt.imshow(xx2[0])

# %%
plt.imshow(xx2[1])

# %%
plt.imshow(xx2[15])

# %%
xx2 = np.load('../deeplab/result_la_crf/2007_000032.npy').item()

# %%
plt.imshow(xx2[0])

# %%
plt.imshow(xx2[0])

# %%
plt.imshow(xx2[0])

# %%
plt.imshow(xx2[0])

# %%
plt.imshow(xx2[0])

# %%
plt.imshow(xx2[1])

# %%
plt.imshow(xx2[1])

# %%
plt.imshow(xx2[1])

# %%
plt.imshow(xx2[1])

# %%
plt.imshow(xx2[1])

# %%
plt.imshow(xx2[15])

# %%
plt.imshow(xx2[15])

# %%
plt.imshow(xx2[15])

# %%
plt.imshow(xx2[15])

# %%
plt.imshow(xx2[15])

# %%
xx = np.load('../deeplab/result_cam/2007_000032.npy').item()

# %%
plt.imshow(xx[0])

# %%
plt.imshow(xx[0])

# %%
plt.imshow(xx[0])

# %%
plt.imshow(xx[0])

# %%
plt.imshow(xx[0])

# %%
plt.imshow(xx[14])

# %%
plt.imshow(xx[14])

# %%
plt.imshow(xx[14])

# %%
plt.imshow(xx[14])

# %%
plt.imshow(xx[14])

# %%
v
